# %% [markdown]
# # Building Filter

# %%
import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.pylab as pylab
# %matplotlib inline
import seaborn as sns
sns.set_style("darkgrid")
mpl.style.use('ggplot')

import gc

# %%
data_dir = os.path.join(os.path.dirname(os.getcwd()), 'data/')

meta_path = os.path.join(data_dir, 'metadata/metadata.csv')
meter_dir = os.path.join(data_dir, 'meters/cleaned/')
weather_path = os.path.join(data_dir, 'weather/weather.csv')

for dirname, _, filenames in os.walk(meter_dir):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /Users/jiaqwu/Documents/Eureka/A_Projects/0000_Repository/building-data-genome-project-2/data/meters/cleaned/chilledwater_cleaned.csv
# /Users/jiaqwu/Documents/Eureka/A_Projects/0000_Repository/building-data-genome-project-2/data/meters/cleaned/steam_cleaned.csv
# /Users/jiaqwu/Documents/Eureka/A_Projects/0000_Repository/building-data-genome-project-2/data/meters/cleaned/hotwater_cleaned.csv
# /Users/jiaqwu/Documents/Eureka/A_Projects/0000_Repository/building-data-genome-project-2/data/meters/cleaned/gas_cleaned.csv
# /Users/jiaqwu/Documents/Eureka/A_Projects/0000_Repository/building-data-genome-project-2/data/meters/cleaned/irrigation_cleaned.csv
# /Users/jiaqwu/Documents/Eureka/A_Projects/0000_Repository/building-data-genome-project-2/data/meters/cleaned/electricity_cleaned.csv
# /Users/jiaqwu/Documents/Eureka/A_Projects/0000_Repository/building-data-genome-project-2/data/meters/cleaned/solar_cleaned.csv
# /Users/jiaqwu/Documents/Eureka/A_Projects/0000_Repository/building-data-genome-project-2/data/meters/cleaned/water_cleaned.csv

# %% [markdown]
# ### Metadata

# %%
metadata = pd.read_csv(meta_path)
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1636 entries, 0 to 1635
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   building_id            1636 non-null   object
#  1   site_id                1636 non-null   object
#  2   building_id_kaggle     1449 non-null   float64
#  3   site_id_kaggle         1599 non-null   float64
#  4   primaryspaceusage      1615 non-null   object
#  5   sub_primaryspaceusage  1615 non-null   object
#  6   sqm                    1636 non-null   float64
#  7   sqft                   1636 non-null   float64
#  8   lat                    1399 non-null   float64
#  9   lng                    1399 non-null   float64
#  10  timezone               1636 non-null   object
#  11  electricity            1578 non-null   object
#  12  hotwater               185 non-null    object
#  13  chilledwater           555 non-null    object
#  14  steam                  370 non-null    object
#  15  water                  146 non-null    object
#  16  irrigation             37 non-null     object
#  17  solar                  5 non-null      object
#  18  gas                    177 non-null    object
#  19  industry               579 non-null    object
#  20  subindustry            579 non-null    object
#  21  heatingtype            215 non-null    object
#  22  yearbuilt              817 non-null    float64
#  23  date_opened            21 non-null     object
#  24  numberoffloors         441 non-null    float64
#  25  occupants              230 non-null    float64
#  26  energystarscore        163 non-null    object
#  27  eui                    299 non-null    object
#  28  site_eui               163 non-null    object
#  29  source_eui             163 non-null    object
#  30  leed_level             16 non-null     object
#  31  rating                 184 non-null    object
# dtypes: float64(9), object(23)
# memory usage: 409.1+ KB

# %%
education = metadata[metadata['primaryspaceusage'] == 'Education']
education.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 617 entries, 3 to 1625
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   building_id            617 non-null    object
#  1   site_id                617 non-null    object
#  2   building_id_kaggle     549 non-null    float64
#  3   site_id_kaggle         617 non-null    float64
#  4   primaryspaceusage      617 non-null    object
#  5   sub_primaryspaceusage  617 non-null    object
#  6   sqm                    617 non-null    float64
#  7   sqft                   617 non-null    float64
#  8   lat                    573 non-null    float64
#  9   lng                    573 non-null    float64
#  10  timezone               617 non-null    object
#  11  electricity            604 non-null    object
#  12  hotwater               81 non-null     object
#  13  chilledwater           234 non-null    object
#  14  steam                  147 non-null    object
#  15  water                  50 non-null     object
#  16  irrigation             4 non-null      object
#  17  solar                  3 non-null      object
#  18  gas                    100 non-null    object
#  19  industry               271 non-null    object
#  20  subindustry            271 non-null    object
#  21  heatingtype            105 non-null    object
#  22  yearbuilt              382 non-null    float64
#  23  date_opened            0 non-null      object
#  24  numberoffloors         211 non-null    float64
#  25  occupants              103 non-null    float64
#  26  energystarscore        26 non-null     object
#  27  eui                    61 non-null     object
#  28  site_eui               26 non-null     object
#  29  source_eui             26 non-null     object
#  30  leed_level             4 non-null      object
#  31  rating                 99 non-null     object
# dtypes: float64(9), object(23)
# memory usage: 159.1+ KB

# %%
edu_electricity = education[education['electricity'].notna()]
edu_electricity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 604 entries, 3 to 1625
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   building_id            604 non-null    object
#  1   site_id                604 non-null    object
#  2   building_id_kaggle     542 non-null    float64
#  3   site_id_kaggle         604 non-null    float64
#  4   primaryspaceusage      604 non-null    object
#  5   sub_primaryspaceusage  604 non-null    object
#  6   sqm                    604 non-null    float64
#  7   sqft                   604 non-null    float64
#  8   lat                    561 non-null    float64
#  9   lng                    561 non-null    float64
#  10  timezone               604 non-null    object
#  11  electricity            604 non-null    object
#  12  hotwater               81 non-null     object
#  13  chilledwater           229 non-null    object
#  14  steam                  141 non-null    object
#  15  water                  47 non-null     object
#  16  irrigation             2 non-null      object
#  17  solar                  3 non-null      object
#  18  gas                    98 non-null     object
#  19  industry               266 non-null    object
#  20  subindustry            266 non-null    object
#  21  heatingtype            105 non-null    object
#  22  yearbuilt              372 non-null    float64
#  23  date_opened            0 non-null      object
#  24  numberoffloors         208 non-null    float64
#  25  occupants              102 non-null    float64
#  26  energystarscore        24 non-null     object
#  27  eui                    54 non-null     object
#  28  site_eui               24 non-null     object
#  29  source_eui             24 non-null     object
#  30  leed_level             4 non-null      object
#  31  rating                 99 non-null     object
# dtypes: float64(9), object(23)
# memory usage: 155.7+ KB

# %%
edu_electricity['building_id'].unique()
# Out:
# array(['Panther_education_Rosalie', 'Panther_education_Misty',
#        'Panther_education_Mattie', 'Panther_education_Diann',
#        'Panther_education_Gina', 'Panther_education_Tina',
#        'Panther_education_Vincent', 'Panther_education_Shelton',
#        'Panther_education_Sophia', 'Panther_education_Annetta',
#        'Panther_education_Aurora', 'Panther_education_Karri',
#        'Panther_education_Hugh', 'Panther_education_Mohammad',
#        'Panther_education_Jonathan', 'Panther_education_Genevieve',
#        'Panther_education_Alecia', 'Panther_education_Quintin',
#        'Panther_education_Teofila', 'Panther_education_Ivan',
#        'Panther_education_Edna', 'Panther_education_Violet',
#        'Panther_education_Neal', 'Panther_education_Zelda',
#        'Panther_education_Jerome', 'Panther_education_Enriqueta',
#        'Panther_education_Janis', 'Panther_education_Emily',
#        'Panther_education_Scarlett', 'Panther_education_Cleopatra',
#        'Robin_education_Kiera', 'Robin_education_Della',
#        'Robin_education_Lashandra', 'Robin_education_Megan',
#        'Robin_education_Mercedes', 'Robin_education_Audrea',
#        'Robin_education_Derrick', 'Robin_education_Karyl',
#        'Robin_education_Madeline', 'Robin_education_Leslie',
#        'Robin_education_So', 'Robin_education_Jasper',
#        'Robin_education_Cecilia', 'Robin_education_Julius',
#        'Robin_education_Margarito', 'Robin_education_Zenia',
#        'Robin_education_Derick', 'Robin_education_Terrance',
#        'Robin_education_Kristopher', 'Robin_education_Billi',
#        'Robin_education_Takako', 'Robin_education_Lizbeth',
#        'Fox_education_Vernon', 'Fox_education_Charles',
#        'Fox_education_Kendrick', 'Fox_education_Delma',
#        'Fox_education_Ollie', 'Fox_education_Andre',
#        'Fox_education_Yolande', 'Fox_education_Rosie',
#        'Fox_education_Tonya', 'Fox_education_Nilda', 'Fox_education_Kim',
#        'Fox_education_Maris', 'Fox_education_Elvira',
#        'Fox_education_Leota', 'Fox_education_Heriberto',
#        'Fox_education_Miguelina', 'Fox_education_Maureen',
#        'Fox_education_Sterling', 'Fox_education_Elois',
#        'Fox_education_Geoffrey', 'Fox_education_Gayla',
#        'Fox_education_Gloria', 'Fox_education_Wendell',
#        'Fox_education_Claude', 'Fox_education_Jaclyn',
#        'Fox_education_Etta', 'Fox_education_Otilia',
#        'Fox_education_Eldon', 'Fox_education_Janina',
#        'Fox_education_Long', 'Fox_education_Leona',
#        'Fox_education_Dominique', 'Fox_education_Theodore',
#        'Fox_education_Melinda', 'Fox_education_Willis',
#        'Fox_education_Elizabeth', 'Fox_education_Eddy',
#        'Fox_education_Shawanda', 'Fox_education_Stacia',
#        'Fox_education_Rudolph', 'Fox_education_Louie',
#        'Fox_education_Ashli', 'Fox_education_Dewayne',
#        'Fox_education_Shirley', 'Fox_education_Marlana',
#        'Fox_education_Melvin', 'Fox_education_Lilly',
#        'Fox_education_Virginia', 'Fox_education_Marcelina',
#        'Fox_education_Virgil', 'Fox_education_Suzan',
#        'Fox_education_Lesley', 'Fox_education_Burton',
#        'Fox_education_Shaun', 'Fox_education_Cynthia',
#        'Fox_education_Jacqueline', 'Fox_education_Tamika',
#        'Fox_education_Claire', 'Fox_education_Kris',
#        'Fox_education_Carleen', 'Fox_education_Henrietta',
#        'Fox_education_Ray', 'Fox_education_John',
#        'Rat_education_Angelica', 'Rat_education_Moises',
#        'Rat_education_Colin', 'Rat_education_Denise',
#        'Rat_education_Wilmer', 'Rat_education_Conrad',
#        'Rat_education_Rogelio', 'Rat_education_Calvin',
#        'Rat_education_Debra', 'Rat_education_Mac', 'Rat_education_Lonnie',
#        'Rat_education_Kandice', 'Rat_education_Barbara',
#        'Rat_education_Dreama', 'Rat_education_Renee',
#        'Rat_education_Nellie', 'Rat_education_Winnie',
#        'Rat_education_Kelsey', 'Rat_education_Leonardo',
#        'Rat_education_Rosalyn', 'Rat_education_Theo',
#        'Rat_education_Marcos', 'Rat_education_Earnest',
#        'Rat_education_Eleonora', 'Rat_education_Zina',
#        'Rat_education_Elisa', 'Rat_education_Francisca',
#        'Rat_education_Mavis', 'Rat_education_Penny',
#        'Rat_education_Paula', 'Rat_education_Earl',
#        'Rat_education_Veronica', 'Rat_education_Nydia',
#        'Rat_education_Fernando', 'Rat_education_Pat',
#        'Rat_education_Milagros', 'Rat_education_Barney',
#        'Rat_education_Dann', 'Rat_education_Royal',
#        'Rat_education_Bryant', 'Rat_education_Cinthia',
#        'Rat_education_Lynn', 'Rat_education_Meghan',
#        'Rat_education_Ulrike', 'Rat_education_Sherwood',
#        'Rat_education_Carmela', 'Rat_education_Chance',
#        'Rat_education_Willie', 'Rat_education_Jacob',
#        'Rat_education_Davis', 'Rat_education_Mona',
#        'Rat_education_Marvin', 'Rat_education_Shellie',
#        'Rat_education_Terese', 'Rat_education_Jeanne',
#        'Rat_education_Stuart', 'Rat_education_Alyson',
#        'Rat_education_Kathryn', 'Rat_education_Donnell',
#        'Rat_education_Candida', 'Rat_education_Adrian',
#        'Rat_education_Mose', 'Rat_education_Jesse',
#        'Rat_education_Tristan', 'Rat_education_Maricela',
#        'Rat_education_Nona', 'Rat_education_Keith',
#        'Rat_education_Romana', 'Rat_education_Imelda',
#        'Rat_education_Dana', 'Rat_education_Brett', 'Rat_education_Jena',
#        'Rat_education_Lincoln', 'Rat_education_Morton',
#        'Rat_education_Guillermo', 'Rat_education_Zoe',
#        'Rat_education_Roxanne', 'Rat_education_Patty',
#        'Rat_education_Liz', 'Rat_education_Adell',
#        'Rat_education_Beverly', 'Rat_education_Alfred',
#        'Rat_education_Everett', 'Rat_education_Edmund',
#        'Rat_education_Esther', 'Rat_education_Alonzo',
#        'Rat_education_Matt', 'Rat_education_Alfonso',
#        'Rat_education_Robyn', 'Rat_education_Verna',
#        'Rat_education_Vicky', 'Rat_education_Lee', 'Rat_education_Irma',
#        'Rat_education_Abigail', 'Rat_education_Tim',
#        'Rat_education_Elsie', 'Rat_education_Humberto',
#        'Rat_education_Cedric', 'Rat_education_Willy',
#        'Rat_education_Cecil', 'Rat_education_Marianna',
#        'Rat_education_Susana', 'Rat_education_Dianne',
#        'Rat_education_Sina', 'Rat_education_Deanna', 'Rat_education_Yu',
#        'Rat_education_Kristie', 'Rat_education_Jame',
#        'Rat_education_Gricelda', 'Rat_education_Salvatore',
#        'Rat_education_Tania', 'Bear_education_Yvette',
#        'Bear_education_Arnold', 'Bear_education_Carlo',
#        'Bear_education_Maryjane', 'Bear_education_Owen',
#        'Bear_education_Marta', 'Bear_education_Babara',
#        'Bear_education_Herb', 'Bear_education_Darrell',
#        'Bear_education_Pattie', 'Bear_education_Wade',
#        'Bear_education_Holly', 'Bear_education_Danna',
#        'Bear_education_Sandy', 'Bear_education_Liliana',
#        'Bear_education_Paola', 'Bear_education_Austin',
#        'Bear_education_Bob', 'Bear_education_Deborah',
#        'Bear_education_Lorie', 'Bear_education_Nanette',
#        'Bear_education_Val', 'Bear_education_Thuy',
#        'Bear_education_Deena', 'Bear_education_Irene',
#        'Bear_education_Curtis', 'Bear_education_Benjamin',
#        'Bear_education_Marie', 'Bear_education_Merrill',
#        'Bear_education_Benita', 'Bear_education_Mara',
#        'Bear_education_Gavin', 'Bear_education_Rebecca',
#        'Bear_education_Lashanda', 'Bear_education_Patricia',
#        'Bear_education_Katy', 'Bear_education_Derek',
#        'Bear_education_Bulah', 'Bear_education_Lila',
#        'Bear_education_Lewis', 'Bear_education_Chun',
#        'Bear_education_Destiny', 'Bear_education_Sharon',
#        'Bear_education_Chana', 'Bear_education_Yuri', 'Bear_education_Wm',
#        'Bear_education_Oscar', 'Bear_education_Clint',
#        'Bear_education_Herman', 'Bear_education_Millie',
#        'Bear_education_Alfredo', 'Bear_education_Bonita',
#        'Bear_education_Tara', 'Bear_education_Santos',
#        'Bear_education_Alvaro', 'Bear_education_Lidia',
#        'Bear_education_Marsha', 'Bear_education_Wilton',
#        'Bear_education_Iris', 'Bear_education_Zandra',
#        'Bear_education_Fannie', 'Bear_education_Leonel',
#        'Bear_education_Shelley', 'Bear_education_Augusta',
#        'Bear_education_Chad', 'Bear_education_Laurette',
#        'Bear_education_Elise', 'Lamb_education_Emery',
#        'Lamb_education_Ruben', 'Lamb_education_Manuel',
#        'Lamb_education_Mae', 'Lamb_education_Princess',
#        'Lamb_education_Bettye', 'Lamb_education_Aldo',
#        'Lamb_education_Lucas', 'Lamb_education_Freddy',
#        'Lamb_education_Moses', 'Lamb_education_Sara',
#        'Lamb_education_Phil', 'Lamb_education_Sabrina',
#        'Lamb_education_Darrel', 'Lamb_education_Isabelle',
#        'Lamb_education_Norris', 'Lamb_education_Logan',
#        'Lamb_education_Rick', 'Lamb_education_Gabriel',
#        'Lamb_education_Gabrielle', 'Lamb_education_Kayla',
#        'Lamb_education_Hubert', 'Lamb_education_Harold',
#        'Lamb_education_Dolly', 'Lamb_education_Antonio',
#        'Lamb_education_Lawrence', 'Lamb_education_Hellen',
#        'Lamb_education_Daniel', 'Lamb_education_Renae',
#        'Lamb_education_Wilbert', 'Lamb_education_Salvador',
#        'Lamb_education_Sylvester', 'Lamb_education_Dwayne',
#        'Lamb_education_Marc', 'Lamb_education_Stefan',
#        'Lamb_education_Hui', 'Lamb_education_Randal',
#        'Lamb_education_Bert', 'Lamb_education_Maxwell',
#        'Lamb_education_Sunny', 'Lamb_education_Junior',
#        'Lamb_education_Augustine', 'Lamb_education_Terina',
#        'Lamb_education_Camille', 'Lamb_education_Ira',
#        'Lamb_education_Nathan', 'Lamb_education_Lemuel',
#        'Lamb_education_Williams', 'Lamb_education_Hilary',
#        'Lamb_education_Armando', 'Lamb_education_Ellen',
#        'Lamb_education_Domitila', 'Lamb_education_Maritza',
#        'Lamb_education_Faith', 'Lamb_education_Patsy',
#        'Lamb_education_Eula', 'Lamb_education_Nichol',
#        'Lamb_education_Mckenzie', 'Lamb_education_Wanda',
#        'Lamb_education_Debby', 'Lamb_education_Hillary',
#        'Lamb_education_Larissa', 'Lamb_education_Fred',
#        'Lamb_education_Carlton', 'Lamb_education_Rodrigo',
#        'Lamb_education_Marty', 'Lamb_education_Heidi',
#        'Lamb_education_Jane', 'Lamb_education_Garry',
#        'Lamb_education_Alina', 'Lamb_education_Felipe',
#        'Lamb_education_Vaughn', 'Lamb_education_Luz',
#        'Lamb_education_Leopoldo', 'Lamb_education_Robin',
#        'Lamb_education_Kasha', 'Lamb_education_Traci',
#        'Lamb_education_Lazaro', 'Lamb_education_Philomena',
#        'Lamb_education_Willetta', 'Lamb_education_Chet',
#        'Lamb_education_Emilie', 'Lamb_education_Felicia',
#        'Peacock_education_Anita', 'Peacock_education_Patience',
#        'Peacock_education_Pasquale', 'Peacock_education_Yolanda',
#        'Peacock_education_Bianca', 'Peacock_education_Shelly',
#        'Peacock_education_Robbie', 'Peacock_education_Joshua',
#        'Peacock_education_Forest', 'Peacock_education_Dustin',
#        'Peacock_education_Ophelia', 'Peacock_education_Karyn',
#        'Peacock_education_Lyle', 'Peacock_education_Weldon',
#        'Peacock_education_Gilberto', 'Peacock_education_Lucie',
#        'Peacock_education_Karl', 'Moose_education_Sasha',
#        'Moose_education_Ricardo', 'Moose_education_Lori',
#        'Moose_education_Gladys', 'Moose_education_Maria',
#        'Moose_education_Marlon', 'Moose_education_Clark',
#        'Moose_education_Rene', 'Moose_education_Leland',
#        'Moose_education_Marina', 'Moose_education_Abbie',
#        'Moose_education_Florence', 'Moose_education_Diane',
#        'Bull_education_Clarice', 'Bull_education_Roseann',
#        'Bull_education_Brenda', 'Bull_education_Brady',
#        'Bull_education_Antonia', 'Bull_education_Dakota',
#        'Bull_education_Annette', 'Bull_education_Lydia',
#        'Bull_education_Kristal', 'Bull_education_Bryon',
#        'Bull_education_Reynaldo', 'Bull_education_Reina',
#        'Bull_education_Sebastian', 'Bull_education_Miquel',
#        'Bull_education_Summer', 'Bull_education_Pamela',
#        'Bull_education_Fabiola', 'Bull_education_Miranda',
#        'Bull_education_Shona', 'Bull_education_Carl',
#        'Bull_education_Jeffery', 'Bull_education_Mario',
#        'Bull_education_Krista', 'Bull_education_Venita',
#        'Bull_education_Brain', 'Bull_education_Nichole',
#        'Bull_education_Pablo', 'Bull_education_Arthur',
#        'Bull_education_Elva', 'Bull_education_Brandi',
#        'Bull_education_Magaret', 'Bull_education_Genie',
#        'Bull_education_Geneva', 'Bull_education_Patrina',
#        'Bull_education_Lyn', 'Bull_education_Kendra',
#        'Bull_education_Clarita', 'Bull_education_Roland',
#        'Bull_education_Jae', 'Bull_education_Nolan',
#        'Bull_education_Mervin', 'Bull_education_Delia',
#        'Bull_education_Barry', 'Bull_education_Violeta',
#        'Bull_education_Dan', 'Bull_education_Dania',
#        'Bull_education_Bernice', 'Bull_education_Nina',
#        'Bull_education_Racheal', 'Bull_education_Linnie',
#        'Bull_education_Hayley', 'Bull_education_Juan',
#        'Bull_education_Gregory', 'Bull_education_Myra',
#        'Bull_education_Tracey', 'Bull_education_Joseph',
#        'Bull_education_Luke', 'Bull_education_Dora',
#        'Bull_education_Olive', 'Bull_education_Dottie',
#        'Bull_education_Matilda', 'Bull_education_Lenny',
#        'Bull_education_Stewart', 'Bobcat_education_Miki',
#        'Bobcat_education_Barbra', 'Bobcat_education_Coleman',
#        'Bobcat_education_Alissa', 'Bobcat_education_Angela',
#        'Bobcat_education_Whitney', 'Bobcat_education_Marisha',
#        'Bobcat_education_Toni', 'Bobcat_education_Rodrick',
#        'Bobcat_education_Karin', 'Bobcat_education_Monte',
#        'Bobcat_education_Jayne', 'Bobcat_education_Dylan',
#        'Bobcat_education_Rosalva', 'Bobcat_education_Hollis',
#        'Bobcat_education_Seth', 'Bobcat_education_Emile',
#        'Crow_education_Marlin', 'Crow_education_Keisha',
#        'Crow_education_Kate', 'Crow_education_Winston',
#        'Crow_education_Omer', 'Wolf_education_Anisa',
#        'Wolf_education_Roderick', 'Wolf_education_Katie',
#        'Wolf_education_Josefa', 'Wolf_education_Ursula',
#        'Wolf_education_Laurinda', 'Wolf_education_Cheryl',
#        'Wolf_education_Vivian', 'Wolf_education_Cody',
#        'Wolf_education_Tori', 'Wolf_education_Eulalia',
#        'Wolf_education_Clarissa', 'Wolf_education_Joaquin',
#        'Wolf_education_Tammie', 'Wolf_education_Dolores',
#        'Wolf_education_Miguel', 'Wolf_education_Loren',
#        'Wolf_education_Arnulfo', 'Wolf_education_Dorris',
#        'Wolf_education_Bobby', 'Hog_education_Darryl',
#        'Hog_education_Jared', 'Hog_education_Leandro',
#        'Hog_education_Roberto', 'Hog_education_Janell',
#        'Hog_education_Hallie', 'Hog_education_Robert',
#        'Hog_education_Sonia', 'Hog_education_Wayne',
#        'Hog_education_George', 'Hog_education_Casandra',
#        'Hog_education_Bruno', 'Hog_education_Rachael',
#        'Hog_education_Odell', 'Hog_education_Caridad',
#        'Hog_education_Haywood', 'Hog_education_Cathleen',
#        'Hog_education_Beth', 'Hog_education_Jordan', 'Hog_education_Josh',
#        'Hog_education_Luvenia', 'Hog_education_Jewel',
#        'Hog_education_Donnie', 'Hog_education_Madge',
#        'Eagle_education_Eileen', 'Eagle_education_April',
#        'Eagle_education_Maragret', 'Eagle_education_Jewell',
#        'Eagle_education_Paul', 'Eagle_education_Sheena',
#        'Eagle_education_Shante', 'Eagle_education_Shanna',
#        'Eagle_education_Luther', 'Eagle_education_Samantha',
#        'Eagle_education_Petra', 'Eagle_education_Brooke',
#        'Eagle_education_Wesley', 'Eagle_education_Norah',
#        'Eagle_education_Cassie', 'Eagle_education_Lino',
#        'Eagle_education_Edith', 'Eagle_education_Peter',
#        'Eagle_education_Teresa', 'Eagle_education_Raul',
#        'Eagle_education_Sherrill', 'Eagle_education_Roman',
#        'Eagle_education_Alberto', 'Eagle_education_Shana',
#        'Eagle_education_Will', 'Eagle_education_Brianne',
#        'Cockatoo_education_Julio', 'Cockatoo_education_Brigitte',
#        'Cockatoo_education_Orlando', 'Cockatoo_education_Laurence',
#        'Cockatoo_education_Jack', 'Cockatoo_education_Erik',
#        'Cockatoo_education_Rita', 'Cockatoo_education_Brendan',
#        'Cockatoo_education_Lionel', 'Cockatoo_education_Latrice',
#        'Cockatoo_education_Melanie', 'Cockatoo_education_Janet',
#        'Cockatoo_education_Eunice', 'Cockatoo_education_Flora',
#        'Cockatoo_education_Christi', 'Cockatoo_education_Minh',
#        'Cockatoo_education_Doreen', 'Cockatoo_education_Mayra',
#        'Cockatoo_education_Charity', 'Cockatoo_education_Jon',
#        'Cockatoo_education_Helene', 'Cockatoo_education_Maynard',
#        'Cockatoo_education_Evangeline', 'Cockatoo_education_Nelda',
#        'Cockatoo_education_Tyler', 'Cockatoo_education_Terrence',
#        'Cockatoo_education_June', 'Cockatoo_education_Clifton',
#        'Cockatoo_education_Magdalena', 'Cockatoo_education_Shawn',
#        'Cockatoo_education_Oliver', 'Cockatoo_education_Amira',
#        'Cockatoo_education_Julia', 'Cockatoo_education_Sheryl',
#        'Cockatoo_education_Claudine', 'Cockatoo_education_Deloris',
#        'Cockatoo_education_Joel', 'Cockatoo_education_Joeann',
#        'Cockatoo_education_Marva', 'Cockatoo_education_Collin',
#        'Cockatoo_education_Gussie', 'Cockatoo_education_Arlen',
#        'Cockatoo_education_Victoria'], dtype=object)
