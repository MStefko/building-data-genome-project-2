# %% [markdown]
# # Install IBM-Granite/granite-tsfm repository
#
# This notebook installs the IBM Time Series Foundation Model repository.

# %%
# Install ibm/tsfm
! pip install "tsfm_public[notebooks] @ git+ssh://git@github.com/ibm-granite/granite-tsfm.git"
# Out:
# Collecting tsfm_public@ git+ssh://****@github.com/ibm-granite/granite-tsfm.git (from tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Cloning ssh://****@github.com/ibm-granite/granite-tsfm.git to /private/var/folders/zj/mdsgjw6j6l1g69s02_k6y2g40000gp/T/pip-install-cjzesd_f/tsfm-public_d41ea9f7ae7146f494205411a853fb35
#   Running command git clone --filter=blob:none --quiet 'ssh://****@github.com/ibm-granite/granite-tsfm.git' /private/var/folders/zj/mdsgjw6j6l1g69s02_k6y2g40000gp/T/pip-install-cjzesd_f/tsfm-public_d41ea9f7ae7146f494205411a853fb35
#   Resolved ssh://****@github.com/ibm-granite/granite-tsfm.git to commit f856e5bfc739dc23b2a2dace13bbe3b45d21ceee
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas>=2.2.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2.2.2)
# Requirement already satisfied: scikit-learn in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.5.1)
# Collecting transformers>=4.38.0 (from transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached transformers-4.44.2-py3-none-any.whl.metadata (43 kB)
# Collecting datasets (from tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Collecting deprecated (from tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: urllib3<2,>=1.26.19 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.26.20)
# Requirement already satisfied: numpy<2 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.26.4)
# Collecting jupyter (from tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: matplotlib in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (3.9.2)
# Collecting ipywidgets (from tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting plotly (from tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached plotly-5.24.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: kaleido in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.2.1)
# Collecting tensorboard (from tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached tensorboard-2.17.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from pandas>=2.2.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from pandas>=2.2.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from pandas>=2.2.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2023.3)
# Requirement already satisfied: filelock in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (3.15.4)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached huggingface_hub-0.24.6-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2024.7.24)
# Requirement already satisfied: requests in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.4.4)
# Collecting tokenizers<0.20,>=0.19 (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached tokenizers-0.19.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (4.66.5)
# Collecting accelerate>=0.21.0 (from transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached accelerate-0.34.0-py3-none-any.whl.metadata (19 kB)
# Collecting torch (from transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached torch-2.4.1-cp312-none-macosx_11_0_arm64.whl.metadata (26 kB)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from datasets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from datasets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.3.8)
# Requirement already satisfied: xxhash in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from datasets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (3.5.0)
# Collecting multiprocess (from datasets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2024.6.1)
# Collecting aiohttp (from datasets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached aiohttp-3.10.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from deprecated->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.16.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from ipywidgets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from ipywidgets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (8.25.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from ipywidgets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from ipywidgets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from ipywidgets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (3.0.13)
# Collecting notebook (from jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached notebook-7.2.2-py3-none-any.whl.metadata (10 kB)
# Collecting jupyter-console (from jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting nbconvert (from jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached nbconvert-7.16.4-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: ipykernel in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (6.28.0)
# Collecting jupyterlab (from jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached jupyterlab-4.2.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from matplotlib->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from matplotlib->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from matplotlib->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from matplotlib->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.4.4)
# Requirement already satisfied: pillow>=8 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from matplotlib->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from matplotlib->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (3.1.4)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from plotly->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (9.0.0)
# Requirement already satisfied: scipy>=1.6.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from scikit-learn->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from scikit-learn->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from scikit-learn->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (3.5.0)
# Requirement already satisfied: absl-py>=0.4 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from tensorboard->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from tensorboard->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.66.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from tensorboard->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from tensorboard->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (5.28.0)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from tensorboard->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (72.1.0)
# Requirement already satisfied: six>1.9 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from tensorboard->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from tensorboard->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from tensorboard->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (3.0.4)
# Requirement already satisfied: psutil in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from accelerate>=0.21.0->transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (5.9.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from aiohttp->datasets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2.4.0)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from aiohttp->datasets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from aiohttp->datasets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from aiohttp->datasets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from aiohttp->datasets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.9.11)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (4.12.2)
# Requirement already satisfied: decorator in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2.15.1)
# Requirement already satisfied: stack-data in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from requests->transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from requests->transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (3.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from requests->transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2024.8.30)
# Requirement already satisfied: sympy in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from torch->transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.13.2)
# Requirement already satisfied: networkx in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from torch->transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (3.3)
# Collecting jinja2 (from torch->transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2.1.5)
# Requirement already satisfied: appnope in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from ipykernel->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from ipykernel->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from ipykernel->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from ipykernel->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (5.7.2)
# Requirement already satisfied: nest-asyncio in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from ipykernel->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from ipykernel->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from ipykernel->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (6.4.1)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2.0.4)
# Collecting httpx>=0.25.0 (from jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached jupyter_server-2.14.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting notebook-shim>=0.2 (from jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting beautifulsoup4 (from nbconvert->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: bleach!=5.0.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from nbconvert->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (6.1.0)
# Requirement already satisfied: defusedxml in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from nbconvert->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from nbconvert->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from nbconvert->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (3.0.2)
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached nbclient-0.10.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting nbformat>=5.7 (from nbconvert->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from nbconvert->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.5.1)
# Requirement already satisfied: tinycss2 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from nbconvert->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.3.0)
# Requirement already satisfied: webencodings in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.5.1)
# Collecting anyio (from httpx>=0.25.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: sniffio in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (3.10.0)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: overrides>=5.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.9.25)
# Collecting jsonschema>=4.18.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2.20.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2.6)
# Requirement already satisfied: executing in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.8.3)
# Requirement already satisfied: asttokens in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from sympy->torch->transformers[torch]>=4.38.0->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.3.0)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl.metadata (6.7 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: referencing>=0.28.4 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.20.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (0.1.1)
# Requirement already satisfied: fqdn in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.5.1)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (3.0.0)
# Requirement already satisfied: uri-template in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (24.8.0)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached cffi-1.17.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Requirement already satisfied: pycparser in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2.22)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git)
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/jiaqwu/miniconda3/envs/bdg2/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git->tsfm_public[notebooks]@ git+ssh://git@github.com/ibm-granite/granite-tsfm.git) (2.9.0.20240821)
# Using cached transformers-4.44.2-py3-none-any.whl (9.5 MB)
# Using cached datasets-2.21.0-py3-none-any.whl (527 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Using cached jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Using cached plotly-5.24.0-py3-none-any.whl (19.0 MB)
# Using cached tensorboard-2.17.1-py3-none-any.whl (5.5 MB)
# Using cached accelerate-0.34.0-py3-none-any.whl (324 kB)
# Using cached aiohttp-3.10.5-cp312-cp312-macosx_11_0_arm64.whl (389 kB)
# Using cached huggingface_hub-0.24.6-py3-none-any.whl (417 kB)
# Using cached tokenizers-0.19.1-cp312-cp312-macosx_11_0_arm64.whl (2.4 MB)
# Using cached torch-2.4.1-cp312-none-macosx_11_0_arm64.whl (62.1 MB)
# Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Using cached jupyterlab-4.2.5-py3-none-any.whl (11.6 MB)
# Using cached multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Using cached nbconvert-7.16.4-py3-none-any.whl (257 kB)
# Using cached notebook-7.2.2-py3-none-any.whl (5.0 MB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached httpx-0.27.2-py3-none-any.whl (76 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Using cached jupyter_server-2.14.2-py3-none-any.whl (383 kB)
# Using cached jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Using cached nbclient-0.10.0-py3-none-any.whl (25 kB)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached anyio-4.4.0-py3-none-any.whl (86 kB)
# Using cached argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Using cached argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl (53 kB)
# Using cached cffi-1.17.1-cp312-cp312-macosx_11_0_arm64.whl (178 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached arrow-1.3.0-py3-none-any.whl (66 kB)
# Building wheels for collected packages: tsfm_public
#   Building wheel for tsfm_public (pyproject.toml) ... done
#   Created wheel for tsfm_public: filename=tsfm_public-0.2.9-py3-none-any.whl size=2317357 sha256=ef5cc4a62ae64013bedaae673c1b97212a143921335102c360811581b8b3b9e1
#   Stored in directory: /private/var/folders/zj/mdsgjw6j6l1g69s02_k6y2g40000gp/T/pip-ephem-wheel-cache-mfo_6xb5/wheels/d6/1d/66/966018c9e92db78b29713671cc2c1295252f403f89a9f06aa1
# Successfully built tsfm_public
# Installing collected packages: plotly, multiprocess, jinja2, httpcore, deprecated, cffi, beautifulsoup4, anyio, aiosignal, torch, tensorboard, jupyter-server-terminals, jsonschema-specifications, huggingface-hub, httpx, arrow, argon2-cffi-bindings, aiohttp, tokenizers, jsonschema, isoduration, argon2-cffi, accelerate, transformers, nbformat, ipywidgets, datasets, nbclient, jupyter-events, jupyter-console, tsfm_public, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter
# Successfully installed accelerate-0.34.0 aiohttp-3.10.5 aiosignal-1.3.1 anyio-4.4.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 beautifulsoup4-4.12.3 cffi-1.17.1 datasets-2.21.0 deprecated-1.2.14 httpcore-1.0.5 httpx-0.27.2 huggingface-hub-0.24.6 ipywidgets-8.1.5 isoduration-20.11.0 jinja2-3.1.4 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.10.0 jupyter-lsp-2.2.5 jupyter-server-2.14.2 jupyter-server-terminals-0.5.3 jupyterlab-4.2.5 jupyterlab-server-2.27.3 multiprocess-0.70.16 nbclient-0.10.0 nbconvert-7.16.4 nbformat-5.10.4 notebook-7.2.2 notebook-shim-0.2.4 plotly-5.24.0 tensorboard-2.17.1 tokenizers-0.19.1 torch-2.4.1 transformers-4.44.2 tsfm_public-0.2.9

# %%
# Check installation
from tsfm_public.models.tinytimemixer import TinyTimeMixerForPrediction


model_512 = TinyTimeMixerForPrediction.from_pretrained("ibm/TTM", revision="main")
model_512.config.context_length
# Out:
# 512

# %%
# Check for another tsfm model
model_1024 = TinyTimeMixerForPrediction.from_pretrained("ibm/TTM", revision="1024_96_v1")
model_1024.config.num_patches
# Out:
# config.json:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.80M [00:00<?, ?B/s]
# 16
